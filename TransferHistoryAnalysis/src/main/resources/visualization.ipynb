# %%
import pandas as pd
import matplotlib.pyplot as plt

churnAnalysis = pd.read_csv('flatMapResult.csv',names=['dates','number'])
churnAnalysis.head()
# Out:
#      dates  number
# 0  2017-02       1
# 1  2017-03      31
# 2  2017-04      48
# 3  2017-05      86
# 4  2017-06     379

# %%
# %matplotlib inline
x = churnAnalysis['dates']
y = churnAnalysis['number']
plt.figure(figsize=(28,10))
plt.plot(x,y)
plt.show()
